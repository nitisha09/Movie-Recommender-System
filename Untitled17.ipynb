# %%
import pandas as pd
import numpy as np

# %%
ratings=pd.read_csv("/content/ratings.csv")

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
movies=pd.read_csv("/content/movies.csv")

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_data=pd.merge(ratings,movies,on='movieId')
movie_data.head()
# Out:
#    userId  movieId  rating   timestamp                title  \
# 0       1      296     5.0  1147880044  Pulp Fiction (1994)
# 1       3      296     5.0  1439474476  Pulp Fiction (1994)
# 2       4      296     4.0  1573938898  Pulp Fiction (1994)
# 3       5      296     4.0   830786155  Pulp Fiction (1994)
# 4       7      296     4.0   835444730  Pulp Fiction (1994)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
movie_data.groupby('title')['rating'].mean().head()
# Out:
# title
# "Great Performances" Cats (1998)    3.541667
# #realityhigh (2017)                 3.000000
# $ (Dollars) (1971)                  4.000000
# $5 a Day (2008)                     3.666667
# $9.99 (2008)                        2.666667
# Name: rating, dtype: float64

# %%
#sort the avg rating
movie_data.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Adventures of Picasso, The (Picassos äventyr) (1978)    5.0
# Remembrance (2011)                                      5.0
# Rehearsals for Extinct Anatomies (1987)                 5.0
# Shut In (2016)                                          5.0
# Schmatta: Rags to Riches to Rags (2009)                 5.0
# Name: rating, dtype: float64

# %%
#total no. of ratings
movie_data.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Forrest Gump (1994)                 3518
# Shawshank Redemption, The (1994)    3488
# Pulp Fiction (1994)                 3418
# Silence of the Lambs, The (1991)    3227
# Matrix, The (1999)                  3064
# Name: rating, dtype: int64

# %%
#avg ratings with no. of ratings
ratings_mean_count=pd.DataFrame(movie_data.groupby('title')['rating'].mean())
ratings_mean_count.head()
# Out:
#                                     rating
# title
# "Great Performances" Cats (1998)  3.541667
# #realityhigh (2017)               3.000000
# $ (Dollars) (1971)                4.000000
# $5 a Day (2008)                   3.666667
# $9.99 (2008)                      2.666667

# %%
ratings_mean_count['num of ratings'] = pd.DataFrame(movie_data.groupby('title')['rating'].count())
ratings_mean_count.head()
# Out:
#                                     rating  num of ratings
# title
# "Great Performances" Cats (1998)  3.541667              12
# #realityhigh (2017)               3.000000               1
# $ (Dollars) (1971)                4.000000               1
# $5 a Day (2008)                   3.666667               3
# $9.99 (2008)                      2.666667               3

# %%
plt.figure(figsize=(10,4))
ratings_mean_count['num of ratings'].hist(bins=70)

# %%
plt.figure(figsize=(10,4))
ratings_mean_count['rating'].hist(bins=70)

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings_mean_count,alpha=0.5)

# %%
moviemat = movie_data.pivot_table(index='userId',columns='title',values='rating')
moviemat.head()
# Out:
# title   "Great Performances" Cats (1998)  #realityhigh (2017)  \
# userId
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  NaN
# 4                                    NaN                  NaN
# 5                                    NaN                  NaN
#
# title   $ (Dollars) (1971)  $5 a Day (2008)  $9.99 (2008)  '71 (2014)  \
# userId
# 1                      NaN              NaN           NaN         NaN
# 2                      NaN              NaN           NaN         NaN
# 3                      NaN              NaN           NaN         NaN
# 4                      NaN              NaN           NaN         NaN
# 5                      NaN              NaN           NaN         NaN
#
# title   'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
#
# title   'Neath the Arizona Skies (1934)  'R Xmas (2001)  \
# userId
# 1                                   NaN             NaN
# 2                                   NaN             NaN
# 3                                   NaN             NaN
# 4                                   NaN             NaN
# 5                                   NaN             NaN
#
# title   'Round Midnight (1986)  ...  Когда зажигаются ёлки (1950)  \
# userId                          ...
# 1                          NaN  ...                           NaN
# 2                          NaN  ...                           NaN
# 3                          NaN  ...                           NaN
# 4                          NaN  ...                           NaN
# 5                          NaN  ...                           NaN
#
# title   Ландыш серебристый (2000)  Мартынко (1987)  Мафия (2016)  Начальник  \
# userId
# 1                             NaN              NaN           NaN        NaN
# 2                             NaN              NaN           NaN        NaN
# 3                             NaN              NaN           NaN        NaN
# 4                             NaN              NaN           NaN        NaN
# 5                             NaN              NaN           NaN        NaN
#
# title   Обезьянки и грабители (1985)  Он вам не Димон (2017)  \
# userId
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
# 5                                NaN                     NaN
#
# title   Приключения Домовёнка (1986)  Принцесса и Людоед (1977)  \
# userId
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                        NaN
# 4                                NaN                        NaN
# 5                                NaN                        NaN
#
# title   Я худею (2018)
# userId
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
#
# [5 rows x 22226 columns]

# %%
ratings_mean_count.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                              rating  num of ratings
# title
# Forrest Gump (1994)                        4.057987            3518
# Shawshank Redemption, The (1994)           4.436067            3488
# Pulp Fiction (1994)                        4.182417            3418
# Silence of the Lambs, The (1991)           4.131546            3227
# Matrix, The (1999)                         4.160738            3064
# Star Wars: Episode IV - A New Hope (1977)  4.101160            2931
# Jurassic Park (1993)                       3.687432            2745
# Schindler's List (1993)                    4.276031            2545
# Fight Club (1999)                          4.226285            2530
# Braveheart (1995)                          3.997417            2516

# %%
forestgump_user_ratings= moviemat['Forrest Gump (1994)']

forestgump_user_ratings.head()
# Out:
# userId
# 1    NaN
# 2    4.5
# 3    4.0
# 4    NaN
# 5    4.0
# Name: Forrest Gump (1994), dtype: float64

# %%
similar_to_forrestgump = moviemat.corrwith(forrestgump_user_ratings)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_forrestgump = pd.DataFrame(similar_to_forrestgump,columns=['Correlation'])
corr_forrestgump.dropna(inplace=True)
corr_forrestgump.head()
# Out:
#                                          Correlation
# title
# "Great Performances" Cats (1998)            0.249029
# $9.99 (2008)                               -1.000000
# '71 (2014)                                  0.244375
# 'Hellboy': The Seeds of Creation (2004)     0.188982
# 'Round Midnight (1986)                      1.000000

# %%
corr_forrestgump.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Я худею (2018)                                              1.0
# Dimensions of Dialogue (Moznosti dialogu) (1982)            1.0
# An Inspector Calls (2015)                                   1.0
# Diego Maradona (2019)                                       1.0
# My Sister Eileen (1955)                                     1.0
# My Sweet Little Village (1985)                              1.0
# Mysterious Object at Noon (Dokfa nai meuman) (2...          1.0
# And So It Goes (2014)                                       1.0
# Detour (2017)                                               1.0
# Destiny (a.k.a. Between Two Worlds) (Der müde T...          1.0

# %%
corr_forrestgump = corr_forrestgump.join(ratings_mean_count['num of ratings'])
corr_forrestgump.head()
# Out:
#                                          Correlation  num of ratings
# title
# "Great Performances" Cats (1998)            0.249029              12
# $9.99 (2008)                               -1.000000               3
# '71 (2014)                                  0.244375              19
# 'Hellboy': The Seeds of Creation (2004)     0.188982               5
# 'Round Midnight (1986)                      1.000000               7

# %%
corr_forrestgump[corr_forrestgump['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Forrest Gump (1994)                                    1.000000
# Don't Be a Menace to South Central While Drinki...     0.518184
# Red Dawn (1984)                                        0.482307
# Escape from Alcatraz (1979)                            0.478397
# Life of David Gale, The (2003)                         0.474072
#
#                                                     num of ratings
# title
# Forrest Gump (1994)                                           3518
# Don't Be a Menace to South Central While Drinki...             113
# Red Dawn (1984)                                                122
# Escape from Alcatraz (1979)                                    117
# Life of David Gale, The (2003)                                 106
